# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Path to the cloned repository directory
repo_directory = "/content/drive/MyDrive/RAG-end2end"

# Change the current working directory to the cloned repository directory
os.chdir(repo_directory)

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/RAG-end2end'

# %%
# %ls
# Out:
# Data-NoteBook.ipynb  Experiments/            Nishauri_2_0_colab.ipynb       rag/
# Endpoints/           lightning_logs/         Nishauri_2_0.ipynb             rag-end2end-retriever/
# evaluation/          Nishauri_2_0_aws.ipynb  Nishauri_2_0_lightining.ipynb  README.md

# %%
# %ls rag-end2end-retriever/Health-data/health-data/
# Out:
# my_knowledge_dataset/                  NishauriGPT-Data.csv
# my_knowledge_dataset_hnsw_index.faiss  NishauriGPT-Data.tsv

# %%
import pandas as pd

data = pd.read_csv("rag-end2end-retriever/Health-data/health-data/NishauriGPT-Data.tsv", sep="\t")

data.head(10)
# Out:
#   title                                                           \
# 0  Candidiasis (thrush)                          ...
# 1  Symptoms of Candidiasis (thrush)              ...
# 2  Causes of Candidiasis (thrush)                ...
# 3  Treatment of Candidiasis (thrush)             ...
# 4  Cryptococcosis                                ...
# 5  Symptoms of  Cryptococcosis                   ...
# 6  Symptoms of Cryptococcosis                    ...
# 7  Symptoms of Cryptococcosis                    ...
# 8  Treatment of Cryptococcosis                   ...
# 9  Treatment of Cryptococcosis                   ...
#
#                                                 text
# 0  Candidiasis, also commonly referred to as thru...
# 1  Oral thrush: White patches on tongue/cheeks, b...
# 2  Weakened immune system,Antibiotics disrupting ...
# 3  Treatment: Antifungal medications (clotrimazol...
# 4  Cryptococcosis is a fungal infection caused by...
# 5  Pulmonary cryptococcosis: Mimics pneumonia wit...
# 6  Cryptococcal meningitis (most common in immuno...
# 7  Disseminated cryptococcosis: Can affect skin, ...
# 8  Antifungal medications like fluconazole, itrac...
# 9  In immunocompromised individuals, lifelong ant...

# %%
# check for missing values
data.isna().sum()
# Out:
# title                                                             0
# text                                                              0
# dtype: int64

# %%
# checking for uniformity
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 2 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   title                                                           92 non-null     object
#  1   text                                                            92 non-null     object
# dtypes: object(2)
# memory usage: 1.6+ KB

# %%
# checking for duplicated values
data.duplicated().sum()
# Out:
# 0
